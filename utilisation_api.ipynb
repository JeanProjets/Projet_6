# %% [markdown]
# # Utilisation de l'API - OpenFood Facts
#
# This notebook demonstrates how to query the OpenFood Facts API to collect product data for marketplace expansion. We'll specifically search for "champagne" products to extend the product range with fine food items.

# %%
import requests
import base64
import requests
import pandas as pd
url = "https://world.openfoodfacts.org/api/v2/search?ing=sugar&page_size=10&fields=code,product_name,categories,ingredients_text,image_url"

# Build the Basic Auth header ("off:off" → base64)
auth_string = base64.b64encode(b"off:off").decode("utf-8")
headers = {
    "Authorization": "Basic " + auth_string
}

response = requests.get(url, headers=headers)

# Parse JSON
data = response.json()

print(data)
# Out:
# {'count': 4190677, 'page': 1, 'page_count': 10, 'page_size': 10, 'products': [{'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Unsweetened beverages,Natural mineral waters', 'code': '6111035000430', 'image_url': 'https://images.openfoodfacts.org/images/products/611/103/500/0430/front_en.104.400.jpg', 'ingredients_text': 'OBD1 999 999 1112606 266963207 mb', 'product_name': 'Sidi Ali'}, {'categories': 'Dairies,Fermented foods,Fermented milk products,Snacks,Desserts,Dairy desserts,Fermented dairy desserts,Plain fermented dairy desserts,Plain fermented dairy desserts with cream', 'code': '6111242100992', 'image_url': 'https://images.openfoodfacts.org/images/products/611/124/210/0992/front_fr.131.400.jpg', 'ingredients_text': 'milk cream, cream, sugar, banana, bacteria', 'product_name': 'perly'}, {'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Natural mineral waters', 'code': '6111035002175', 'image_url': 'https://images.openfoodfacts.org/images/products/611/103/500/2175/front_fr.118.400.jpg', 'ingredients_text': 'Sodium, Calcium, Magnésium, Potassium, Bicarbonates, Sulfates, Chlorures,', 'product_name': 'Sidi Ali'}, {'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Unsweetened beverages,Natural mineral waters', 'code': '6111035000058', 'image_url': 'https://images.openfoodfacts.org/images/products/611/103/500/0058/front_en.121.400.jpg', 'ingredients_text': '100% mineral water', 'product_name': 'Eau minérale naturelle'}, {'categories': 'Boissons et préparations de boissons,Boissons,Eaux,Eaux de sources,Eaux minérales,Eaux de table', 'code': '6111252421568', 'image_url': 'https://images.openfoodfacts.org/images/products/611/125/242/1568/front_en.62.400.jpg', 'ingredients_text': 'ouverture et avant le : Voir bouteille. après مياه مصفاة بتقنية اكوافينا هايدرو - 7 Eau purifiée par la technique Aquafina HydRO-7', 'product_name': 'اكوافينا'}, {'categories': 'Dairies,Meals,Milks (liquid and powder),Milks,Semi-skimmed milks', 'code': '6111266962187', 'image_url': 'https://images.openfoodfacts.org/images/products/611/126/696/2187/front_fr.56.400.jpg', 'ingredients_text': 'Lait frais pasteurisé demi-écrémé à 15g/l de matière grasse', 'product_name': 'Lait'}, {'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Unsweetened beverages,Natural mineral waters', 'code': '3274080005003', 'image_url': 'https://images.openfoodfacts.org/images/products/327/408/000/5003/front_en.797.400.jpg', 'ingredients_text': 'Eau de source', 'product_name': 'Eau De Source'}, {'categories': 'Dairies,Fermented foods,Fermented milk products,Cheeses,Desserts,Dairy desserts,Fermented dairy desserts,Fromages blancs - petit suisses and skyr,Plain fermented dairy desserts,fr:Fromages blancs,fr:Fromages blancs natures', 'code': '6111246721261', 'image_url': 'https://images.openfoodfacts.org/images/products/611/124/672/1261/front_en.14.400.jpg', 'ingredients_text': 'Ferments lactiques, Présure, Sel.', 'product_name': 'Fromage blanc nature'}, {'categories': 'Dairies,Milks,Homogenized milks,UHT Milks,Whole milks,Cow milks,Whole milk UHT', 'code': '6111242101180', 'image_url': 'https://images.openfoodfacts.org/images/products/611/124/210/1180/front_fr.79.400.jpg', 'ingredients_text': 'Lait entier', 'product_name': 'uht jaouda 1L'}, {'categories': 'en:Dairies, en:Fermented foods, en:Fermented milk products, en:Spreads, en:Cheeses, en:Salted spreads, en:Cheese spreads, en:Fromage frais nature à 21%de matière grasse', 'code': '6111242106949', 'image_url': 'https://images.openfoodfacts.org/images/products/611/124/210/6949/front_fr.77.400.jpg', 'ingredients_text': 'lait frais entier, crème, stabilisants, amidon, carraghénane, sel, ferments lactiques\nmatière grasse 21%', 'product_name': 'Jben'}], 'skip': 0}

# %%
data
# Out:
# {'count': 4190677,
#  'page': 1,
#  'page_count': 10,
#  'page_size': 10,
#  'products': [{'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Unsweetened beverages,Natural mineral waters',
#    'code': '6111035000430',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/103/500/0430/front_en.104.400.jpg',
#    'ingredients_text': 'OBD1 999 999 1112606 266963207 mb',
#    'product_name': 'Sidi Ali'},
#   {'categories': 'Dairies,Fermented foods,Fermented milk products,Snacks,Desserts,Dairy desserts,Fermented dairy desserts,Plain fermented dairy desserts,Plain fermented dairy desserts with cream',
#    'code': '6111242100992',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/124/210/0992/front_fr.131.400.jpg',
#    'ingredients_text': 'milk cream, cream, sugar, banana, bacteria',
#    'product_name': 'perly'},
#   {'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Natural mineral waters',
#    'code': '6111035002175',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/103/500/2175/front_fr.118.400.jpg',
#    'ingredients_text': 'Sodium, Calcium, Magnésium, Potassium, Bicarbonates, Sulfates, Chlorures,',
#    'product_name': 'Sidi Ali'},
#   {'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Unsweetened beverages,Natural mineral waters',
#    'code': '6111035000058',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/103/500/0058/front_en.121.400.jpg',
#    'ingredients_text': '100% mineral water',
#    'product_name': 'Eau minérale naturelle'},
#   {'categories': 'Boissons et préparations de boissons,Boissons,Eaux,Eaux de sources,Eaux minérales,Eaux de table',
#    'code': '6111252421568',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/125/242/1568/front_en.62.400.jpg',
#    'ingredients_text': 'ouverture et avant le : Voir bouteille. après مياه مصفاة بتقنية اكوافينا هايدرو - 7 Eau purifiée par la technique Aquafina HydRO-7',
#    'product_name': 'اكوافينا'},
#   {'categories': 'Dairies,Meals,Milks (liquid and powder),Milks,Semi-skimmed milks',
#    'code': '6111266962187',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/126/696/2187/front_fr.56.400.jpg',
#    'ingredients_text': 'Lait frais pasteurisé demi-écrémé à 15g/l de matière grasse',
#    'product_name': 'Lait'},
#   {'categories': 'Beverages and beverages preparations,Beverages,Waters,Spring waters,Mineral waters,Unsweetened beverages,Natural mineral waters',
#    'code': '3274080005003',
#    'image_url': 'https://images.openfoodfacts.org/images/products/327/408/000/5003/front_en.797.400.jpg',
#    'ingredients_text': 'Eau de source',
#    'product_name': 'Eau De Source'},
#   {'categories': 'Dairies,Fermented foods,Fermented milk products,Cheeses,Desserts,Dairy desserts,Fermented dairy desserts,Fromages blancs - petit suisses and skyr,Plain fermented dairy desserts,fr:Fromages blancs,fr:Fromages blancs natures',
#    'code': '6111246721261',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/124/672/1261/front_en.14.400.jpg',
#    'ingredients_text': 'Ferments lactiques, Présure, Sel.',
#    'product_name': 'Fromage blanc nature'},
#   {'categories': 'Dairies,Milks,Homogenized milks,UHT Milks,Whole milks,Cow milks,Whole milk UHT',
#    'code': '6111242101180',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/124/210/1180/front_fr.79.400.jpg',
#    'ingredients_text': 'Lait entier',
#    'product_name': 'uht jaouda 1L'},
#   {'categories': 'en:Dairies, en:Fermented foods, en:Fermented milk products, en:Spreads, en:Cheeses, en:Salted spreads, en:Cheese spreads, en:Fromage frais nature à 21%de matière grasse',
#    'code': '6111242106949',
#    'image_url': 'https://images.openfoodfacts.org/images/products/611/124/210/6949/front_fr.77.400.jpg',
#    'ingredients_text': 'lait frais entier, crème, stabilisants, amidon, carraghénane, sel, ferments lactiques\nmatière grasse 21%',
#    'product_name': 'Jben'}],
#  'skip': 0}

# %%
# ———————— Parse Results ————————


products = data.get("products", [])

rows = []
for product in products:
    rows.append({
        "foodId": product.get("code", ""),
        "label": product.get("product_name", ""),
        "category": product.get("categories", ""),
        "foodContentsLabel": product.get("ingredients_text", ""),
        "image": product.get("image_url", "")
    })

# ———————— DataFrame & CSV ————————
df = pd.DataFrame(rows)

csv_filename = f"products_result.csv"
df.to_csv(csv_filename, index=False, encoding="utf-8")

print(f"Saved {len(df)} products to {csv_filename}")
# Out:
# Saved 10 products to products_result.csv

# %%
df
# Out:
#           foodId                   label  \
# 0  6111035000430                Sidi Ali
# 1  6111242100992                   perly
# 2  6111035002175                Sidi Ali
# 3  6111035000058  Eau minérale naturelle
# 4  6111252421568                اكوافينا
# 5  6111266962187                    Lait
# 6  3274080005003           Eau De Source
# 7  6111246721261    Fromage blanc nature
# 8  6111242101180           uht jaouda 1L
# 9  6111242106949                    Jben
#
#                                             category  \
# 0  Beverages and beverages preparations,Beverages...
# 1  Dairies,Fermented foods,Fermented milk product...
# 2  Beverages and beverages preparations,Beverages...
# 3  Beverages and beverages preparations,Beverages...
# 4  Boissons et préparations de boissons,Boissons,...
# 5  Dairies,Meals,Milks (liquid and powder),Milks,...
# 6  Beverages and beverages preparations,Beverages...
# 7  Dairies,Fermented foods,Fermented milk product...
# 8  Dairies,Milks,Homogenized milks,UHT Milks,Whol...
# 9  en:Dairies, en:Fermented foods, en:Fermented m...
#
#                                    foodContentsLabel  \
# 0                  OBD1 999 999 1112606 266963207 mb
# 1         milk cream, cream, sugar, banana, bacteria
# 2  Sodium, Calcium, Magnésium, Potassium, Bicarbo...
# 3                                 100% mineral water
# 4  ouverture et avant le : Voir bouteille. après ...
# 5  Lait frais pasteurisé demi-écrémé à 15g/l de m...
# 6                                      Eau de source
# 7                  Ferments lactiques, Présure, Sel.
# 8                                        Lait entier
# 9  lait frais entier, crème, stabilisants, amidon...
#
#                                                image
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3  https://images.openfoodfacts.org/images/produc...
# 4  https://images.openfoodfacts.org/images/produc...
# 5  https://images.openfoodfacts.org/images/produc...
# 6  https://images.openfoodfacts.org/images/produc...
# 7  https://images.openfoodfacts.org/images/produc...
# 8  https://images.openfoodfacts.org/images/produc...
# 9  https://images.openfoodfacts.org/images/produc...

# %% [markdown]
# ## Champagne Product Search
#
# As per project requirements, we search for "champagne" products to extend the marketplace's fine food category.

# %%
# Search for champagne products
search_term = "champagne"
page_size = 10

# OpenFood Facts API endpoint for search
url = f"https://world.openfoodfacts.org/cgi/search.pl?search_terms={search_term}&search_simple=1&action=process&json=1&page_size={page_size}&fields=code,product_name,categories,ingredients_text,image_url"

# Build the Basic Auth header
auth_string = base64.b64encode(b"off:off").decode("utf-8")
headers = {
    "Authorization": "Basic " + auth_string,
    "User-Agent": "Python-OpenFoodFacts-Client"
}

print(f"Searching for '{search_term}' products...")
response = requests.get(url, headers=headers)

# Parse JSON
champagne_data = response.json()

print(f"Found {champagne_data.get('count', 0)} total products matching '{search_term}'")
print(f"Retrieved {len(champagne_data.get('products', []))} products")
# Out:
# Searching for 'champagne' products...
# Found 1571 total products matching 'champagne'
# Retrieved 10 products

# %%
# Display the raw response structure
champagne_data
# Out:
# {'count': 1571,
#  'page': 1,
#  'page_count': 10,
#  'page_size': 10,
#  'products': [{'categories': 'Produits,Champagnes',
#    'code': '8001841769189',
#    'image_url': 'https://images.openfoodfacts.org/images/products/800/184/176/9189/front_fr.3.400.jpg'},
#   {'categories': "Aliments et boissons à base de végétaux, Aliments d'origine végétale, Aliments à base de fruits et de légumes, Légumineuses et dérivés, Légumineuses, Graines, Légumes et dérivés, Graines de légumineuses, Légumineuses sèches, Lentilles, Lentilles vertes",
#    'code': '3039820510250',
#    'image_url': 'https://images.openfoodfacts.org/images/products/303/982/051/0250/front_fr.68.400.jpg',
#    'ingredients_text': 'Lentilles vertes.',
#    'product_name': 'Vivien Paille Lentilles vertes le paquet de 500 g'},
#   {'categories': 'Salted spreads',
#    'code': '3292070010264',
#    'image_url': 'https://images.openfoodfacts.org/images/products/329/207/001/0264/front_fr.64.400.jpg',
#    'ingredients_text': 'Pois chiches 44% - purée de betterave rouge 37% - huile de colza - purée de framboise 3% - eau - fromage de chèvre (contient lait) 2% - concentré de jus de citron - sel - graines de sésame dorées - graines de nigelle - ail en poudre - conservateur: E202.\r\n\r\nTraces éventuelles de céréales contenant du gluten, crustacés, œufs, poissons, mollusques.',
#    'product_name': 'Betteraves de Champagne & chèvre crémeux, pointe de framboise'},
#   {'categories': 'Boissons, Boissons alcoolisées, Vins, Vins effervescents, Champagnes, Liquide',
#    'code': '3113934004147',
#    'image_url': 'https://images.openfoodfacts.org/images/products/311/393/400/4147/front_fr.4.400.jpg',
#    'ingredients_text': 'Pinots et de Chardonnay',
#    'product_name': 'Canard Duchêne'},
#   {'code': '4820097815556',
#    'image_url': 'https://images.openfoodfacts.org/images/products/482/009/781/5556/front_it.3.400.jpg',
#    'product_name': 'Splashes of champagne'},
#   {'categories': 'Seafood, Fishes and their products, Fish preparations, fr:Rillettes de homard au cognac et champagne, en:lobster-rillettes',
#    'code': '4056489843696',
#    'image_url': 'https://images.openfoodfacts.org/images/products/405/648/984/3696/front_fr.3.400.jpg',
#    'ingredients_text': "Chair de homard américain 49%, huile de colza, colin d'Alaska, eau, double concentré de tomates, Champagne (contient sulfites), moutarde de Dijon (eau, graines de moutarde, vinaigre d'alcool, sel), fibre de blé, jaune d'œuf en poudre, farine de blé, sel, Cognac 0,5%, poivre blanc,",
#    'product_name': 'Rillettes de homard au cognac'},
#   {'categories': "Aliments et boissons à base de végétaux,Aliments d'origine végétale,Légumineuses et dérivés,Légumineuses,Graines,Graines de légumineuses,Légumineuses sèches,Lentilles,Lentilles rosées de Champagne",
#    'code': '3760091726964',
#    'image_url': 'https://images.openfoodfacts.org/images/products/376/009/172/6964/front_fr.34.400.jpg',
#    'ingredients_text': 'Lentilles',
#    'product_name': 'Lentilles roses bio'},
#   {'categories': 'Boissons, Boissons alcoolisées, Vins, Vins effervescents, Champagnes, Champagnes bruts',
#    'code': '3258431220000',
#    'image_url': 'https://images.openfoodfacts.org/images/products/325/843/122/0000/front_en.4.400.jpg',
#    'ingredients_text': 'Champagne',
#    'product_name': ''},
#   {'categories': 'Bebidas, Bebidas alcohólicas, Vinos, Vinos espumosos, Champán',
#    'code': '3114080034057',
#    'image_url': 'https://images.openfoodfacts.org/images/products/311/408/003/4057/front_es.3.400.jpg',
#    'ingredients_text': '',
#    'product_name': 'Champagne rosé'},
#   {'categories': 'Getränke und Getränkezubereitungen, Getränke, Alkoholische Getränke, Weine, Schaumweine, Champagner',
#    'code': '3185370729960',
#    'image_url': 'https://images.openfoodfacts.org/images/products/318/537/072/9960/front_de.3.400.jpg',
#    'ingredients_text': 'IMPERIAL LOOK BEHIND THE SCENES OF OUR MAISON SERIE CALL CONTAINS 12.5% vol 750ml 9.4 UK For further health information visit be drinkaware.co.uk MPORTED BY: MOET HENNESSY UK LIMITED, 18 GROSVENOR GARDENS, LONDON SW ODHUK CHAMPAGNE-BRUT-PRODUIT DE FRANCE - PRODUCT OF FRANCE PRODUCED BY CHAMPAGNE MOET & CHANDON - EPERNAY-FRANCE-NM-549-002',
#    'product_name': 'Br МОЁ HANDON MOET & CHANDON CHAMPAGNE IMPERIAL BR'}],
#  'skip': 0}

# %%
# Parse champagne products into structured format
champagne_products = champagne_data.get("products", [])

champagne_rows = []
for product in champagne_products:
    champagne_rows.append({
        "foodId": product.get("code", ""),
        "label": product.get("product_name", ""),
        "category": product.get("categories", ""),
        "foodContentsLabel": product.get("ingredients_text", ""),
        "image": product.get("image_url", "")
    })

# Create DataFrame
df_champagne = pd.DataFrame(champagne_rows)

print(f"Created DataFrame with {len(df_champagne)} champagne products")
df_champagne
# Out:
# Created DataFrame with 10 champagne products
#           foodId                                              label  \
# 0  8001841769189
# 1  3039820510250  Vivien Paille Lentilles vertes le paquet de 500 g
# 2  3292070010264  Betteraves de Champagne & chèvre crémeux, poin...
# 3  3113934004147                                     Canard Duchêne
# 4  4820097815556                              Splashes of champagne
# 5  4056489843696                      Rillettes de homard au cognac
# 6  3760091726964                                Lentilles roses bio
# 7  3258431220000
# 8  3114080034057                                     Champagne rosé
# 9  3185370729960  Br МОЁ HANDON MOET & CHANDON CHAMPAGNE IMPERIA...
#
#                                             category  \
# 0                                Produits,Champagnes
# 1  Aliments et boissons à base de végétaux, Alime...
# 2                                     Salted spreads
# 3  Boissons, Boissons alcoolisées, Vins, Vins eff...
# 4
# 5  Seafood, Fishes and their products, Fish prepa...
# 6  Aliments et boissons à base de végétaux,Alimen...
# 7  Boissons, Boissons alcoolisées, Vins, Vins eff...
# 8  Bebidas, Bebidas alcohólicas, Vinos, Vinos esp...
# 9  Getränke und Getränkezubereitungen, Getränke, ...
#
#                                    foodContentsLabel  \
# 0
# 1                                  Lentilles vertes.
# 2  Pois chiches 44% - purée de betterave rouge 37...
# 3                            Pinots et de Chardonnay
# 4
# 5  Chair de homard américain 49%, huile de colza,...
# 6                                          Lentilles
# 7                                          Champagne
# 8
# 9  IMPERIAL LOOK BEHIND THE SCENES OF OUR MAISON ...
#
#                                                image
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3  https://images.openfoodfacts.org/images/produc...
# 4  https://images.openfoodfacts.org/images/produc...
# 5  https://images.openfoodfacts.org/images/produc...
# 6  https://images.openfoodfacts.org/images/produc...
# 7  https://images.openfoodfacts.org/images/produc...
# 8  https://images.openfoodfacts.org/images/produc...
# 9  https://images.openfoodfacts.org/images/produc...

# %%
# Save champagne products to CSV
csv_filename = "champagne_products.csv"
df_champagne.to_csv(csv_filename, index=False, encoding="utf-8")

print(f"Saved {len(df_champagne)} champagne products to '{csv_filename}'")
print(f"\nCSV columns: {list(df_champagne.columns)}")
# Out:
# Saved 10 champagne products to 'champagne_products.csv'
#
# CSV columns: ['foodId', 'label', 'category', 'foodContentsLabel', 'image']

# %%
# Verify the saved CSV by reading it back
df_verify = pd.read_csv(csv_filename)
print(f"Verification: CSV contains {len(df_verify)} rows")
print(f"\nSample data:")
df_verify.head()
# Out:
# Verification: CSV contains 10 rows
#
# Sample data:
#           foodId                                              label  \
# 0  8001841769189                                                NaN
# 1  3039820510250  Vivien Paille Lentilles vertes le paquet de 500 g
# 2  3292070010264  Betteraves de Champagne & chèvre crémeux, poin...
# 3  3113934004147                                     Canard Duchêne
# 4  4820097815556                              Splashes of champagne
#
#                                             category  \
# 0                                Produits,Champagnes
# 1  Aliments et boissons à base de végétaux, Alime...
# 2                                     Salted spreads
# 3  Boissons, Boissons alcoolisées, Vins, Vins eff...
# 4                                                NaN
#
#                                    foodContentsLabel  \
# 0                                                NaN
# 1                                  Lentilles vertes.
# 2  Pois chiches 44% - purée de betterave rouge 37...
# 3                            Pinots et de Chardonnay
# 4                                                NaN
#
#                                                image
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3  https://images.openfoodfacts.org/images/produc...
# 4  https://images.openfoodfacts.org/images/produc...

# %% [markdown]
# ## Summary
#
# This notebook demonstrates automated data collection from the OpenFood Facts API:
#
# 1. **API Query**: Successfully queried OpenFood Facts for "champagne" products
# 2. **Data Extraction**: Extracted key fields including:
#    - `foodId`: Unique product identifier (barcode)
#    - `label`: Product name/description
#    - `category`: Product category hierarchy
#    - `foodContentsLabel`: Ingredient information
#    - `image`: Product image URL
#
# 3. **Output**: Saved top 10 champagne products to `champagne_products.csv`
#
# This automated pipeline can be extended to collect more products or search for different terms to expand the marketplace's product catalog.
